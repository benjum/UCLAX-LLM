# %% [markdown]
# # Hugging Face API example

# %% [markdown]
# In the HF LLM course, there is an example I didn't mention among my slides of NLP tasks: mask filling.
# * https://huggingface.co/learn/llm-course/chapter1/3#mask-filling
#
# This task fills in a missing word in a sequence, where the missing word is denoted with a special mask token (such as '\<mask\>' or '[MASK]' or other)

# %% [markdown]
# ## Mask Filling

# %%
unmasker = pipeline("fill-mask")

# %%
unmasker("This course will teach you all about <mask> models.", top_k=2)

# %% [markdown]
# The HF LLM course suggests checking out 'bert-base-cased' on the HF site.
#
# Let's do this:
# * Search for 'bert-base-cased' in the HF page's top search bar.
# * Go to model site
# * Use the Inference Providers widget on the right side to test masking.
# * Grab the code and come back here to paste in the code

# %% [markdown]
# The code we grab will give an error on execution, because we need the HF_TOKEN, i.e. an API key to use the Inference Providers.
#
# We thus need to:
# * Generate token on HF site
# * Use our new token for 'HF_TOKEN'
#   * I will put the API keyt into 'keys.py' and load here via `import keys`

# %%
import keys

# %%
# Use the keys.HF_TOKEN

# %%
result

# %%
result[0].sequence

# %%
for i in result:
    print(i.sequence, i.score)

# %% [markdown]
# # OpenAI Links
# * Developer quickstart: https://platform.openai.com/docs/quickstart
# * API keys: https://platform.openai.com/api-keys
# * Usage: https://platform.openai.com/usage
# * Billing overview: https://platform.openai.com/settings/organization/billing/overview
# * Pricing: https://platform.openai.com/docs/pricing
#
# All of these are from the OpenAI Platform pages, but note that some of these are from the docs (Quickstart and Pricing) and some are not.
#
# Let's do the first Quickstart task.
# * Create an API key
# * Put it into 'keys.py' similar to above
# * Check if we can re-import it
# * Select "Python" for code on the Quickstart page
# * Install the OpenAI SDK in Python <- already done on the JupyterHub
# * Generate a response using gpt-5-nano
